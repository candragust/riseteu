# %% [markdown]
# check

# %%
import pandas as pd

# %%
dfEU = pd.read_csv('EURUSD_H4_25Oct17.csv')

# %%
# Periksa shape
print('shape', dfEU.shape)
# Periksa info
dfEU.info()
# Out:
# shape (12128, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12128 entries, 0 to 12127
# Data columns (total 1 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   datetime	Open	High	Low	Close  12128 non-null  object
# dtypes: object(1)
# memory usage: 94.9+ KB

# %%
# Periksa tipe data
print('tipedata', dfEU.dtypes)

# Periksa kolom
print('Kolom',dfEU.columns)
# Out:
# tipedata datetime\tOpen\tHigh\tLow\tClose    object
# dtype: object
# Kolom Index(['datetime\tOpen\tHigh\tLow\tClose'], dtype='object')

# %%
# Periksa head dan tail
print(dfEU.head())
print(dfEU.tail())
# Out:
#                     datetime\tOpen\tHigh\tLow\tClose
# 0  2018.01.02 00:00\t1.20088\t1.20223\t1.20007\t1...
# 1  2018.01.02 04:00\t1.20152\t1.20245\t1.20069\t1...
# 2  2018.01.02 08:00\t1.20246\t1.20707\t1.20227\t1...
# 3  2018.01.02 12:00\t1.20705\t1.20812\t1.20562\t1...
# 4  2018.01.02 16:00\t1.20572\t1.20591\t1.20261\t1...
#                         datetime\tOpen\tHigh\tLow\tClose
# 12123  2025.10.15 08:00\t1.16183\t1.16454\t1.16174\t1...
# 12124  2025.10.15 12:00\t1.16326\t1.16390\t1.16137\t1...
# 12125  2025.10.15 16:00\t1.16177\t1.16472\t1.16104\t1...
# 12126  2025.10.15 20:00\t1.16400\t1.16476\t1.16268\t1...
# 12127  2025.10.16 00:00\t1.16426\t1.16669\t1.16412\t1...
