# %% [markdown]
# check

# %%
import pandas as pd

# %%
dfEU = pd.read_csv('EURUSD_H4_25Oct17.csv',sep='\t')

# %%
# Periksa shape
print('shape', dfEU.shape)
# Periksa info
dfEU.info()
# Out:
# shape (12128, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12128 entries, 0 to 12127
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  12128 non-null  object
#  1   Open      12128 non-null  float64
#  2   High      12128 non-null  float64
#  3   Low       12128 non-null  float64
#  4   Close     12128 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 473.9+ KB

# %%
# Periksa tipe data
print('tipedata', dfEU.dtypes)

# Periksa kolom
print('Kolom',dfEU.columns)
# Out:
# tipedata datetime     object
# Open        float64
# High        float64
# Low         float64
# Close       float64
# dtype: object
# Kolom Index(['datetime', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# Periksa head dan tail
print(dfEU.head())
print(dfEU.tail())
# Out:
#            datetime     Open     High      Low    Close
# 0  2018.01.02 00:00  1.20088  1.20223  1.20007  1.20146
# 1  2018.01.02 04:00  1.20152  1.20245  1.20069  1.20245
# 2  2018.01.02 08:00  1.20246  1.20707  1.20227  1.20705
# 3  2018.01.02 12:00  1.20705  1.20812  1.20562  1.20574
# 4  2018.01.02 16:00  1.20572  1.20591  1.20261  1.20447
#                datetime     Open     High      Low    Close
# 12123  2025.10.15 08:00  1.16183  1.16454  1.16174  1.16326
# 12124  2025.10.15 12:00  1.16326  1.16390  1.16137  1.16176
# 12125  2025.10.15 16:00  1.16177  1.16472  1.16104  1.16400
# 12126  2025.10.15 20:00  1.16400  1.16476  1.16268  1.16463
# 12127  2025.10.16 00:00  1.16426  1.16669  1.16412  1.16631

# %%
# Check missing values
print(dfEU.isnull().sum())
# Check duplikat
print(dfEU.duplicated().sum())
# Out:
# datetime    0
# Open        0
# High        0
# Low         0
# Close       0
# dtype: int64
# 0

# %%
# Cleansing: Convert datetime to datetime type
dfEU['datetime'] = pd.to_datetime(dfEU['datetime'])

# Check outliers (contoh: boxplot, optional)
#df[['Open', 'High', 'Low', 'Close']].boxplot()

# Hapus duplikat jika ada
#df = df.drop_duplicates()

# Isi missing jika ada (contoh: forward fill)
#df = df.fillna(method='ffill')

# Simpan cleaned data
#df.to_csv('cleaned_EURUSD.csv', index=False)
